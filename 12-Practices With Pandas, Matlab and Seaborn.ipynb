# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

horror_movies = pd.read_csv("horror_movies.csv")
horror_movies.head(10)
# Out:
#         id            original_title                     title  \
# 0   760161        Orphan: First Kill        Orphan: First Kill
# 1   760741                     Beast                     Beast
# 2   882598                     Smile                     Smile
# 3   756999           The Black Phone           The Black Phone
# 4   772450                Presencias                 Presences
# 5  1014226                    Sonríe                    Sonríe
# 6   717728  Jeepers Creepers: Reborn  Jeepers Creepers: Reborn
# 7   762504                      Nope                      Nope
# 8   927341         Hunting Ava Bravo         Hunting Ava Bravo
# 9   760104                         X                         X
#
#   original_language                                           overview  \
# 0                en  After escaping from an Estonian psychiatric fa...
# 1                en  A recently widowed man and his two teenage dau...
# ...

# %%
print (horror_movies.shape)
print (horror_movies.info())
# Out:
# (32540, 20)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32540 entries, 0 to 32539
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 32540 non-null  int64
#  1   original_title     32540 non-null  object
#  2   title              32540 non-null  object
#  3   original_language  32540 non-null  object
#  4   overview           31254 non-null  object
#  5   tagline            12706 non-null  object
#  6   release_date       32540 non-null  object
#  7   poster_path        28066 non-null  object
#  8   popularity         32540 non-null  float64
#  9   vote_count         32540 non-null  int64
#  10  vote_average       32540 non-null  float64
#  11  budget             32540 non-null  int64
#  12  revenue            32540 non-null  int64
#  13  runtime            32540 non-null  int64
#  14  status             32540 non-null  object
# ...

# %%
horror_movies.describe().T
# Out:
#                 count          mean           std    min        25%  \
# id            32540.0  4.459108e+05  3.057447e+05   17.0  146494.75
# popularity    32540.0  4.013456e+00  3.751347e+01    0.0       0.60
# vote_count    32540.0  6.269149e+01  4.208875e+02    0.0       0.00
# vote_average  32540.0  3.335728e+00  2.876002e+00    0.0       0.00
# budget        32540.0  5.431266e+05  4.542668e+06    0.0       0.00
# revenue       32540.0  1.349747e+06  1.443048e+07    0.0       0.00
# runtime       32540.0  6.214290e+01  4.099853e+01    0.0      14.00
# collection     2306.0  4.815349e+05  3.244982e+05  656.0  155421.00
#
#                     50%           75%           max
# id            426521.00  707534.00000  1.033095e+06
# popularity         0.84       2.24325  5.088584e+03
# vote_count         2.00      11.00000  1.690000e+04
# vote_average       4.00       5.70000  1.000000e+01
# budget             0.00       0.00000  2.000000e+08
# ...

# %%
sns.displot(x=horror_movies['original_language'])
