# %%
import numpy as np
import pandas as pd

# %%
# CSV dosyası okuma
top2020 = pd.read_csv("top2020.csv")
top2020
# Out:
#     sel                                           title           artist  \
# 0     1                                 Blinding Lights       The Weeknd
# 1     2                                Watermelon Sugar     Harry Styles
# 2     3                               Someone You Loved    Lewis Capaldi
# 3     4                            lovely (with Khalid)    Billie Eilish
# 4     5                          Mood (feat. iann dior)         24kGoldn
# 5     6                                         Circles      Post Malone
# 6     7                                      goosebumps     Travis Scott
# 7     8                                    Lucid Dreams       Juice WRLD
# 8     9                                        Memories         Maroon 5
# 9    10                                         bad guy    Billie Eilish
# 10   11                    ROCKSTAR (feat. Roddy Ricch)           DaBaby
# 11   12                death bed (coffee for your head)            Powfu
# ...

# %%
top2020["top genre"]
# Out:
# 0     canadian contemporary r&b
# 1                           pop
# 2                           pop
# 3                       art pop
# 4                      cali rap
# 5                       dfw rap
# 6                           rap
# 7                   chicago rap
# 8                           pop
# 9                       art pop
# 10       north carolina hip hop
# 11                      sad rap
# 12                          pop
# 13                          pop
# 14                          rap
# 15              detroit hip hop
# 16                    dance pop
# 17                          rap
# 18                  melodic rap
# 19                    dance pop
# 20                    dance pop
# 21                    dance pop
# 22                      art pop
# 23                    dance pop
# 24                    dance pop
# 25              alternative r&b
# 26                        alt z
# 27                      pop rap
# 28                      dfw rap
# ...

# %%
top2020.artist
# Out:
# 0          The Weeknd
# 1        Harry Styles
# 2       Lewis Capaldi
# 3       Billie Eilish
# 4            24kGoldn
# 5         Post Malone
# 6        Travis Scott
# 7          Juice WRLD
# 8            Maroon 5
# 9       Billie Eilish
# 10             DaBaby
# 11              Powfu
# 12      Lewis Capaldi
# 13       Harry Styles
# 14       Travis Scott
# 15             Eminem
# 16      Ariana Grande
# 17       Travis Scott
# 18        Roddy Ricch
# 19             Regard
# 20            Cardi B
# 21              Topic
# 22      Billie Eilish
# 23           Dua Lipa
# 24           Doja Cat
# 25      Trevor Daniel
# 26            JP Saxe
# 27     Arizona Zervas
# 28        Post Malone
# 29          Surf Mesa
# 30          Jawsh 685
# 31            KAROL G
# 32           Dua Lipa
# 33             Maluma
# 34       Shawn Mendes
# 35           Surfaces
# 36          Bad Bunny
# 37          Lil Mosey
# 38         THE SCOTTS
# 39      Justin Bieber
# 40          Lady Gaga
# ...

# %%
tSayisi=top2020.shape[0]
print (tSayisi)
# Out:
# 50

# %%
kSayisi=top2020.shape[1]
print (kSayisi)
# Out:
# 15

# %%
top2020.dtypes
# Out:
# sel           int64
# title        object
# artist       object
# top genre    object
# year          int64
# bpm           int64
# nrgy          int64
# dnce          int64
# dB            int64
# live          int64
# val           int64
# dur           int64
# acous         int64
# spch          int64
# pop           int64
# dtype: object

# %%
top2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sel        50 non-null     int64
#  1   title      50 non-null     object
#  2   artist     50 non-null     object
#  3   top genre  50 non-null     object
#  4   year       50 non-null     int64
#  5   bpm        50 non-null     int64
#  6   nrgy       50 non-null     int64
#  7   dnce       50 non-null     int64
#  8   dB         50 non-null     int64
#  9   live       50 non-null     int64
#  10  val        50 non-null     int64
#  11  dur        50 non-null     int64
#  12  acous      50 non-null     int64
#  13  spch       50 non-null     int64
#  14  pop        50 non-null     int64
# dtypes: int64(12), object(3)
# memory usage: 6.0+ KB

# %%
artist_title_year = top2020[["sel", "artist", "title", "year"]]
artist_title_year
# Out:
#     sel           artist                                           title  year
# 0     1       The Weeknd                                 Blinding Lights  2020
# 1     2     Harry Styles                                Watermelon Sugar  2019
# 2     3    Lewis Capaldi                               Someone You Loved  2019
# 3     4    Billie Eilish                            lovely (with Khalid)  2018
# 4     5         24kGoldn                          Mood (feat. iann dior)  2021
# 5     6      Post Malone                                         Circles  2019
# 6     7     Travis Scott                                      goosebumps  2016
# 7     8       Juice WRLD                                    Lucid Dreams  2018
# 8     9         Maroon 5                                        Memories  2021
# 9    10    Billie Eilish                                         bad guy  2019
# 10   11           DaBaby                    ROCKSTAR (feat. Roddy Ricch)  2020
# ...

# %%
artist_title_year.sort_values('year', ascending = True)
# Out:
#     sel           artist                                           title  year
# 6     7     Travis Scott                                      goosebumps  2016
# 3     4    Billie Eilish                            lovely (with Khalid)  2018
# 7     8       Juice WRLD                                    Lucid Dreams  2018
# 17   18     Travis Scott                                      SICKO MODE  2018
# 24   25         Doja Cat                                          Say So  2019
# 35   36         Surfaces                                     Sunday Best  2019
# 34   35     Shawn Mendes                                        Señorita  2019
# 31   32          KAROL G                                            Tusa  2019
# 29   30        Surf Mesa            ily (i love you baby) (feat. Emilee)  2019
# 28   29      Post Malone   Sunflower - Spider-Man: Into the Spider-Verse  2019
# 27   28   Arizona Zervas                                         ROXANNE  2019
# ...

# %%
artist_title_year.sort_values(["year", "sel"], ascending = True)
# Out:
#     sel           artist                                           title  year
# 6     7     Travis Scott                                      goosebumps  2016
# 3     4    Billie Eilish                            lovely (with Khalid)  2018
# 7     8       Juice WRLD                                    Lucid Dreams  2018
# 17   18     Travis Scott                                      SICKO MODE  2018
# 1     2     Harry Styles                                Watermelon Sugar  2019
# 2     3    Lewis Capaldi                               Someone You Loved  2019
# 5     6      Post Malone                                         Circles  2019
# 9    10    Billie Eilish                                         bad guy  2019
# 12   13    Lewis Capaldi                                   Before You Go  2019
# 13   14     Harry Styles                                       Adore You  2019
# 14   15     Travis Scott                             HIGHEST IN THE ROOM  2019
# ...

# %%
round(artist_title_year['year'].mean())
# Out:
# 2019

# %%
top2020[top2020.year > 2020]
# Out:
#     sel                   title       artist       top genre  year  bpm  nrgy  \
# 4     5  Mood (feat. iann dior)     24kGoldn        cali rap  2021   91    72
# 8     9                Memories     Maroon 5             pop  2021   91    33
# 41   42            Dance Monkey  Tones And I  australian pop  2021   98    59
#
#     dnce  dB  live  val  dur  acous  spch  pop
# 4     70  -4    32   73  141     17     4   89
# 8     78  -7     8   60  189     84     6   87
# 41    82  -6    15   51  209     69     9   79

# %%
top2020.bpm
# Out:
# 0     171
# 1      95
# 2     110
# 3     115
# 4      91
# 5     120
# 6     130
# 7      84
# 8      91
# 9     135
# 10     90
# 11    144
# 12    112
# 13     99
# 14     76
# 15    166
# 16    179
# 17    155
# 18    117
# 19    118
# 20    133
# 21    122
# 22    120
# 23    124
# 24    111
# 25    127
# 26     76
# 27    117
# 28     90
# 29    112
# 30    150
# 31    101
# 32    113
# 33    180
# 34    117
# 35    112
# 36     96
# 37     99
# 38    130
# 39    148
# 40    123
# 41     98
# 42    147
# 43    114
# 44    142
# 45    146
# 46     82
# 47    105
# 48    129
# 49    122
# Name: bpm, dtype: int64

# %%
top2020[top2020.artist.str.startswith("A")]
# Out:
#     sel                              title          artist  top genre  year  \
# 16   17  Stuck with U (with Justin Bieber)   Ariana Grande  dance pop  2020
# 27   28                            ROXANNE  Arizona Zervas    pop rap  2019
#
#     bpm  nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 16  179    45    60  -7    38   54  228     22     4   86
# 27  117    60    62  -6    46   46  164      5    15   83

# %%
top2020.iloc[:10]
# Out:
#    sel                   title         artist                  top genre  \
# 0    1         Blinding Lights     The Weeknd  canadian contemporary r&b
# 1    2        Watermelon Sugar   Harry Styles                        pop
# 2    3       Someone You Loved  Lewis Capaldi                        pop
# 3    4    lovely (with Khalid)  Billie Eilish                    art pop
# 4    5  Mood (feat. iann dior)       24kGoldn                   cali rap
# 5    6                 Circles    Post Malone                    dfw rap
# 6    7              goosebumps   Travis Scott                        rap
# 7    8            Lucid Dreams     Juice WRLD                chicago rap
# 8    9                Memories       Maroon 5                        pop
# 9   10                 bad guy  Billie Eilish                    art pop
#
#    year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 0  2020  171    73    51  -6     9   33  200      0     6   93
# ...

# %%
top2020[top2020["top genre"] == "rap"]
# Out:
#     sel                title        artist top genre  year  bpm  nrgy  dnce  \
# 6     7           goosebumps  Travis Scott       rap  2016  130    73    84
# 14   15  HIGHEST IN THE ROOM  Travis Scott       rap  2019   76    43    60
# 17   18           SICKO MODE  Travis Scott       rap  2018  155    73    83
# 38   39           THE SCOTTS    THE SCOTTS       rap  2020  130    54    72
#
#     dB  live  val  dur  acous  spch  pop
# 6   -3    15   43  244      8     5   87
# 14  -9    21    6  176      5     3   86
# 17  -4    12   45  313      1    22   85
# 38  -8    16   28  166     23     5   80

# %%
dancesongs = top2020[top2020.dnce > 80]
dancesongs
# Out:
#     sel                             title         artist         top genre  \
# 6     7                        goosebumps   Travis Scott               rap
# 15   16       Godzilla (feat. Juice WRLD)         Eminem   detroit hip hop
# 17   18                        SICKO MODE   Travis Scott               rap
# 18   19                           The Box    Roddy Ricch       melodic rap
# 19   20                           Ride It         Regard         dance pop
# 20   21   WAP (feat. Megan Thee Stallion)        Cardi B         dance pop
# 35   36                       Sunday Best       Surfaces      bedroom soul
# 39   40          Intentions (feat. Quavo)  Justin Bieber      canadian pop
# 41   42                      Dance Monkey    Tones And I    australian pop
# 46   47                      Toosie Slide          Drake  canadian hip hop
# 48   49  Supalonely (feat. Gus Dapperton)          BENEE             alt z
#
#     year  bpm  nrgy  dnce  dB  live  val  dur  acous  spch  pop
# ...

# %%
travis_songs = top2020.artist == "Travis Scott"
travis_songs
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17     True
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: artist, dtype: bool

# %%
top2020[travis_songs]
# Out:
#     sel                title        artist top genre  year  bpm  nrgy  dnce  \
# 6     7           goosebumps  Travis Scott       rap  2016  130    73    84
# 14   15  HIGHEST IN THE ROOM  Travis Scott       rap  2019   76    43    60
# 17   18           SICKO MODE  Travis Scott       rap  2018  155    73    83
#
#     dB  live  val  dur  acous  spch  pop
# 6   -3    15   43  244      8     5   87
# 14  -9    21    6  176      5     3   86
# 17  -4    12   45  313      1    22   85

# %%
top2020[top2020["bpm"] > 120]
# Out:
#     sel                              title         artist  \
# 0     1                    Blinding Lights     The Weeknd
# 6     7                         goosebumps   Travis Scott
# 9    10                            bad guy  Billie Eilish
# 11   12   death bed (coffee for your head)          Powfu
# 15   16        Godzilla (feat. Juice WRLD)         Eminem
# 16   17  Stuck with U (with Justin Bieber)  Ariana Grande
# 17   18                         SICKO MODE   Travis Scott
# 20   21    WAP (feat. Megan Thee Stallion)        Cardi B
# 21   22                        Breaking Me          Topic
# 23   24                    Don't Start Now       Dua Lipa
# 25   26                            Falling  Trevor Daniel
# 30   31   Savage Love (Laxed - Siren Beat)      Jawsh 685
# 33   34                              Hawái         Maluma
# 38   39                         THE SCOTTS     THE SCOTTS
# 39   40           Intentions (feat. Quavo)  Justin Bieber
# ...

# %%
low_bpm = top2020[top2020["bpm"] < 110]
dancy = top2020[top2020["dnce"] > 70]
# top2020[low_bpm & dancy] Bu satır hata verir.
filtered_data = top2020[(top2020["bpm"] < 110) & (top2020["dnce"] > 70)]
filtered_data
# Out:
#     sel                                          title           artist  \
# 8     9                                       Memories         Maroon 5
# 10   11                   ROCKSTAR (feat. Roddy Ricch)           DaBaby
# 28   29  Sunflower - Spider-Man: Into the Spider-Verse      Post Malone
# 31   32                                           Tusa          KAROL G
# 37   38                                Blueberry Faygo        Lil Mosey
# 41   42                                   Dance Monkey      Tones And I
# 46   47                                   Toosie Slide            Drake
# 47   48                      RITMO (Bad Boys For Life)  Black Eyed Peas
#
#                  top genre  year  bpm  nrgy  dnce  dB  live  val  dur  acous  \
# 8                      pop  2021   91    33    78  -7     8   60  189     84
# 10  north carolina hip hop  2020   90    69    75  -8    10   50  182     25
# 28                 dfw rap  2019   90    52    76  -4     7   93  158     53
# ...

# %%
year2016 = top2020["year"] == 2016
top2020[travis_songs & year2016]
# Out:
#    sel       title        artist top genre  year  bpm  nrgy  dnce  dB  live  \
# 6    7  goosebumps  Travis Scott       rap  2016  130    73    84  -3    15
#
#    val  dur  acous  spch  pop
# 6   43  244      8     5   87

# %%
mask = top2020["top genre"].isin(["dance pop", "pop"])
top2020[mask]
# Out:
#     sel                              title           artist  top genre  year  \
# 1     2                   Watermelon Sugar     Harry Styles        pop  2019
# 2     3                  Someone You Loved    Lewis Capaldi        pop  2019
# 8     9                           Memories         Maroon 5        pop  2021
# 12   13                      Before You Go    Lewis Capaldi        pop  2019
# 13   14                          Adore You     Harry Styles        pop  2019
# 16   17  Stuck with U (with Justin Bieber)    Ariana Grande  dance pop  2020
# 19   20                            Ride It           Regard  dance pop  2019
# 20   21    WAP (feat. Megan Thee Stallion)          Cardi B  dance pop  2020
# 21   22                        Breaking Me            Topic  dance pop  2019
# 23   24                    Don't Start Now         Dua Lipa  dance pop  2020
# 24   25                             Say So         Doja Cat  dance pop  2019
# ...

# %%
# mask = df["Team"].isnull()
# Bu da sütunundaki (kolon) Nan değerleri gösterir.
# df[df["Team"].isna()]
