# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
veriler = sns.load_dataset("iris")
veriler
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
type(veriler)
# Out:
# pandas.core.frame.DataFrame

# %%
# creates a line plot using Seaborn.
# x and y parameters specify the columns to use for the x-axis and y-axis
# data=veriler indicates that the data for the plot should be taken 
sns.lineplot(x="sepal_length", y="sepal_width", data=veriler)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
plt.figure(figsize=(18, 9)) # sets the figure size for the plot to 18" wide and 9" tall.
plt.title('Title  Matplotlib Metodunu kullanıyor ') # sets the title of the plot

#This is the same line plot as in the first snippet,
# but it's now part of a larger figure with the specified size and title.
sns.lineplot(x="sepal_length", y="sepal_width", data=veriler)
# Out:
# <Axes: title={'center': 'Title  Matplotlib Metodunu kullanıyor '}, xlabel='sepal_length', ylabel='sepal_width'>

# %%
# https://raw.githubusercontent.com/zaferdemirkol/HerkesIcinYapayZeka/main/reklamlar.csv

# %%
df = pd.read_csv("https://raw.githubusercontent.com/zaferdemirkol/HerkesIcinYapayZeka/main/reklamlar.csv")
df
# Out:
#      Unnamed: 0     TV  radyo  gazete  satışlar     şehir   tür
# 0             0  230.1   37.8    69.2      22.1  İstanbul  Gıda
# 1             1   44.5   39.3    45.1      10.4    Ankara  Gıda
# 2             2   17.2   45.9    69.3       9.3     İzmir  Eşya
# 3             3  151.5   41.3    58.5      18.5     İzmir  Eşya
# 4             4  180.8   10.8    58.4      12.9  İstanbul  Gıda
# ..          ...    ...    ...     ...       ...       ...   ...
# 195         195   38.2    3.7    13.8       7.6  İstanbul  Gıda
# 196         196   94.2    4.9     8.1       9.7  İstanbul  Eşya
# 197         197  177.0    9.3     6.4      12.8  İstanbul  Gıda
# 198         198  283.6   42.0    66.2      25.5  İstanbul  Eşya
# 199         199  232.1    8.6     8.7      13.4    Ankara  Eşya
#
# [200 rows x 7 columns]

# %%
# Dropping a Column
#  removes a column named "Unnamed: 0" (which might be an automatically generated index column)
#  inplace=True modifies the df itself instead of creating a new one. 
# axis=1 specifies that the operation is done on columns (axis=0 would be for rows).

df.drop("Unnamed: 0",inplace=True, axis=1)

# %%
df
# Out:
#         TV  radyo  gazete  satışlar     şehir   tür
# 0    230.1   37.8    69.2      22.1  İstanbul  Gıda
# 1     44.5   39.3    45.1      10.4    Ankara  Gıda
# 2     17.2   45.9    69.3       9.3     İzmir  Eşya
# 3    151.5   41.3    58.5      18.5     İzmir  Eşya
# 4    180.8   10.8    58.4      12.9  İstanbul  Gıda
# ..     ...    ...     ...       ...       ...   ...
# 195   38.2    3.7    13.8       7.6  İstanbul  Gıda
# 196   94.2    4.9     8.1       9.7  İstanbul  Eşya
# 197  177.0    9.3     6.4      12.8  İstanbul  Gıda
# 198  283.6   42.0    66.2      25.5  İstanbul  Eşya
# 199  232.1    8.6     8.7      13.4    Ankara  Eşya
#
# [200 rows x 6 columns]

# %%
# Checking for missing values
# checks for missing values (like NaN) in each column of df and displays the count of missing values.

df.isnull().sum()
# Out:
# TV          0
# radyo       0
# gazete      0
# satışlar    0
# şehir       0
# tür         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   TV        200 non-null    float64
#  1   radyo     200 non-null    float64
#  2   gazete    200 non-null    float64
#  3   satışlar  200 non-null    float64
#  4   şehir     200 non-null    object
#  5   tür       200 non-null    object
# dtypes: float64(4), object(2)
# memory usage: 9.5+ KB

# %%
# uses the displot function to create a distribution plot (histogram) of the values in the "TV" column of df. 
# It uses 5 bins to represent the data distribution.

sns.displot(x=df["TV"], bins=5)

# %%
# counts the occurrences of each unique value in the "şehir" (city) column.
df["şehir"].value_counts()
# Out:
# şehir
# İstanbul    73
# İzmir       66
# Ankara      61
# Name: count, dtype: int64

# %%
# Bar Chart for City Frequency
# As in the previous step plus uses the plot function to create a bar chart showing the frequency of each city.
df["şehir"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='şehir'>

# %%
# Filtering Data by City
# Filters the df to only include rows where the value in the "şehir" column is "İstanbul". 
# This creates a new DataFrame containing only data for Istanbul.

df[df["şehir"]=="İstanbul"]
# Out:
#         TV  radyo  gazete  satışlar     şehir   tür
# 0    230.1   37.8    69.2      22.1  İstanbul  Gıda
# 4    180.8   10.8    58.4      12.9  İstanbul  Gıda
# 10    66.1    5.8    24.2       8.6  İstanbul  Eşya
# 14   204.1   32.9    46.0      19.0  İstanbul  Eşya
# 18    69.2   20.5    18.3      11.3  İstanbul  Gıda
# ..     ...    ...     ...       ...       ...   ...
# 193  166.8   42.0     3.6      19.6  İstanbul  Eşya
# 195   38.2    3.7    13.8       7.6  İstanbul  Gıda
# 196   94.2    4.9     8.1       9.7  İstanbul  Eşya
# 197  177.0    9.3     6.4      12.8  İstanbul  Gıda
# 198  283.6   42.0    66.2      25.5  İstanbul  Eşya
#
# [73 rows x 6 columns]

# %%
# creates a pivot table from df. It uses "şehir" as the row index, 
# "tür" (category) as the column index, 
# "TV" as the value, and calculates the mean (average) using the aggfunc='mean' argument. 
# The resulting pivot_table shows average TV ad spend for each city and category.

pivot_table = df.pivot_table(index='şehir', columns='tür', values='TV', aggfunc='mean')
pivot_table
# Out:
# tür             Eşya        Gıda
# şehir
# Ankara    145.196154  162.157143
# İstanbul  144.409375  158.741463
# İzmir     148.078947  114.335714

# %%
# Filtering by TV Ad Spend
# filters df to include only rows where the value in the "TV" column is greater than 200. 
# This creates a new DataFrame containing data for companies spending more than 200 on TV ads.
df[df["TV"]>200]
# Out:
#         TV  radyo  gazete  satışlar     şehir   tür
# 0    230.1   37.8    69.2      22.1  İstanbul  Gıda
# 11   214.7   24.0     4.0      17.4     İzmir  Eşya
# 14   204.1   32.9    46.0      19.0  İstanbul  Eşya
# 17   281.4   39.6    55.8      24.4     İzmir  Eşya
# 20   218.4   27.7    53.4      18.0  İstanbul  Eşya
# ..     ...    ...     ...       ...       ...   ...
# 184  253.8   21.3    30.0      17.6    Ankara  Eşya
# 185  205.0   45.1    19.6      22.6     İzmir  Eşya
# 188  286.0   13.9     3.7      15.9    Ankara  Gıda
# 198  283.6   42.0    66.2      25.5  İstanbul  Eşya
# 199  232.1    8.6     8.7      13.4    Ankara  Eşya
#
# [67 rows x 6 columns]

# %%
# sets the figure size (width and height) and then uses sns.jointplot to create a scatter plot.
# It shows the relationship between "TV" (x-axis) and "satışlar" (sales, y-axis).
plt.figure(figsize = (40, 14))
sns.jointplot(x=df["TV"], y=df["satışlar"], kind="scatter")

# %%
# Similar to the previous line, this creates a joint plot but uses the "reg" kind to fit a regression line to the data. 
# This helps visualize the overall trend in sales based on TV ad spend.

sns.jointplot(x=df["TV"], y=df["satışlar"], kind="reg")

# %%
# creates a pair plot that shows the relationship between all numerical columns in df
#  using various plots (scatter, histogram) for each pair.
sns.pairplot(df)

# %%
#creates a bar chart similar to the one you saw earlier, 
# but it specifies the colors for each bar using the palette argument. The list ["red", "green", "purple"] 
# assigns these colors to the bars representing the three cities in the "şehir" column.
sns.barplot(x = df['TV'], y = df['şehir'], palette=["red", "green", "purple"])
# Out:
# <ipython-input-47-547460e77e8a>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = df['TV'], y = df['şehir'], palette=["red", "green", "purple"])
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# Calculating Average TV Ad Spend for Each City:
df[df['şehir']=="İstanbul"]["TV"].mean()
# Out:
# 152.45890410958907

# %%
df[df['şehir']=="İzmir"]["TV"].mean()
# Out:
# 133.76363636363638

# %%
df[df['şehir']=="Ankara"]["TV"].mean()
# Out:
# 154.92786885245903

# %%
#  Counting City Occurrences
# creates a count plot that shows the number of occurrences of each unique value in the "şehir" column. 
# It's a simple way to visualize the distribution of cities in the data.
sns.countplot(x=df["şehir"])
# Out:
# <Axes: xlabel='şehir', ylabel='count'>

# %%
# Categorical Count Plot (City vs. Category):
# creates a categorical count plot that shows the distribution of "tür" (category) for each city. 
# The hue argument separates the counts based on the "tür" column, 
# making it easier to compare the frequency of different categories in each city.
sns.catplot(x=df["şehir"], hue=df["tür"], kind="count")
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
# creates a box plot that shows the distribution of the "TV" column. 
# The box plot helps visualize the median, quartiles, and potential outliers in the TV ad spend data.
sns.boxplot(x=df["TV"])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: xlabel='TV'>

# %%
# create box plots that show the distribution of "TV" for each city. 
# The first line has "TV" on the x-axis and "şehir" on the y-axis, while the second line has them reversed. 
# This allows you to compare the TV ad spend distributions across different cities.
sns.boxplot(x=df["TV"], y=df["şehir"])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: xlabel='TV', ylabel='şehir'>

# %%
sns.boxplot(y=df["TV"], x=df["şehir"])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: xlabel='şehir', ylabel='TV'>

# %%
# Creates a violin plot that combines a box plot and a kernel density estimate (KDE) plot. 
# It provides a richer representation of the distribution of "TV" for each city, including the density of data points.
sns.violinplot(y=df["TV"], x=df["şehir"], palette="magma")
# Out:
# <ipython-input-59-ef5759eefa0a>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(y=df["TV"], x=df["şehir"], palette="magma")
# <Axes: xlabel='şehir', ylabel='TV'>

# %%
# Creates a stripplot that shows individual data points for the "TV" column, categorized by the "şehir" column.
# Each dot on the plot represents a specific data point.
# palette="magma" argument sets the color scheme for the dots using the "magma" colormap.
sns.stripplot(y=df["TV"], x=df["şehir"], palette="magma")
# Out:
# <ipython-input-60-e751eca8f435>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(y=df["TV"], x=df["şehir"], palette="magma")
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='şehir', ylabel='TV'>

# %%
# Similar to the stripplot, this plot shows individual data points for "TV" categorized by "şehir".
# However, the swarmplot attempts to avoid overlapping dots by adjusting their positions horizontally.
# This can make it easier to visualize the distribution of data points when there are many overlapping points in the stripplot.
sns.swarmplot(y=df["TV"], x=df["şehir"], palette="magma")
# Out:
# <ipython-input-61-e350b3bf484e>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(y=df["TV"], x=df["şehir"], palette="magma")
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='şehir', ylabel='TV'>

# %%
# Facet Grid (Histograms by City and Category)
# creates a facet grid that arranges histograms in a grid based on the "şehir" and "tür" columns.
# Each cell in the grid represents a combination of city and category.
#The map function applies the sns.histplot function to each cell, 
# creating a histogram of the "TV" column for that specific city and category.
# This visualization helps you compare the distribution of TV ad spend across different cities and categories.
sns.FacetGrid(df, col = 'şehir', row = 'tür').map(sns.histplot, "TV")

# %%
# Linear Regression Plot (Sales vs. TV Ads, Colored by City):
# This line creates a linear regression plot showing the relationship between "TV" (x-axis) and "satışlar" (sales, y-axis).
# The hue="şehir" argument adds a color dimension to the plot, separating the data points based on the "şehir" column.
# This helps visualize how the relationship between TV ads and sales might differ across different cities.
sns.lmplot(x = 'TV', y = 'satışlar', data = df, hue="şehir")

# %% [markdown]
# # Uygulama

# %%
df = sns.load_dataset("taxis")

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
df.shape
# Out:
# (6433, 14)

# %%
satir = df.shape[0]
# Out:
# 6433

# %%
df.isnull().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %%
df.dropna(how="any", axis=0, inplace=True)

# %%
df.shape[0]
# Out:
# 6341

# %%
6433 - 6341
# Out:
# 92

# %%
df.isnull().sum()
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %%
df.dtypes
# Out:
# pickup             datetime64[ns]
# dropoff            datetime64[ns]
# passengers                  int64
# distance                  float64
# fare                      float64
# tip                       float64
# tolls                     float64
# total                     float64
# color                      object
# payment                    object
# pickup_zone                object
# dropoff_zone               object
# pickup_borough             object
# dropoff_borough            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6341 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6341 non-null   datetime64[ns]
#  1   dropoff          6341 non-null   datetime64[ns]
#  2   passengers       6341 non-null   int64
#  3   distance         6341 non-null   float64
#  4   fare             6341 non-null   float64
#  5   tip              6341 non-null   float64
#  6   tolls            6341 non-null   float64
#  7   total            6341 non-null   float64
#  8   color            6341 non-null   object
#  9   payment          6341 non-null   object
#  10  pickup_zone      6341 non-null   object
#  11  dropoff_zone     6341 non-null   object
#  12  pickup_borough   6341 non-null   object
#  13  dropoff_borough  6341 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 743.1+ KB

# %%
sns.displot(x = df['tip'], bins=5)

# %%
sns.histplot(df['tip'])
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.displot(x=df["color"], bins=10)

# %%
colors = ['#FFFF00', '#008000']

sns.countplot(x="color", data=df, palette=colors)
# Out:
# <ipython-input-22-b9f8a31d7f19>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="color", data=df, palette=colors)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='color', ylabel='count'>

# %%
df['color'].value_counts()
# Out:
# color
# yellow    5373
# green      968
# Name: count, dtype: int64

# %%
df[df['pickup_borough'] == "Manhattan"].shape[0]
# Out:
# 5226

# %%
df['pickup_borough'].unique()
# Out:
# array(['Manhattan', 'Queens', 'Bronx', 'Brooklyn'], dtype=object)

# %%
pivot_table = df.pivot_table(index='pickup_borough',
                             columns='color',
                             values='distance',
                             aggfunc='count')

# %%
pivot_table
# Out:
# color           green  yellow
# pickup_borough
# Bronx              83      16
# Brooklyn          310      68
# Manhattan         292    4934
# Queens            283     355

# %%
df.groupby('pickup_borough').agg({'distance': ['mean', 'min', 'max']})
# Out:
#                         distance
#                             mean   min    max
# pickup_borough color
# Bronx          green    5.529277  0.00  23.61
#                yellow   6.745625  0.07  14.74
# Brooklyn       green    3.962548  0.00  25.51
#                yellow   4.774706  0.10  18.70
# Manhattan      green    2.329555  0.00  13.80
#                yellow   2.339945  0.00  28.30
# Queens         green    3.307102  0.00  21.27
#                yellow  10.498873  0.00  36.70

# %%
df.groupby(['pickup_borough', 'color']).agg({'distance': ['mean', 'min', 'max']})

# %%
df[df['distance'] < 0.5]
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 5    2019-03-11 10:37:23 2019-03-11 10:47:31           1      0.49   7.5
# 62   2019-03-21 23:33:55 2019-03-21 23:36:39           1      0.44   4.0
# 81   2019-03-16 18:57:19 2019-03-16 19:00:16           2      0.40   4.0
# 88   2019-03-16 05:08:02 2019-03-16 05:08:20           1      0.07   2.5
# 91   2019-03-11 08:46:09 2019-03-11 08:47:21           1      0.30   3.0
# ...                  ...                 ...         ...       ...   ...
# 6339 2019-03-15 19:49:49 2019-03-15 19:51:18           1      0.15   3.0
# 6355 2019-03-16 13:24:04 2019-03-16 13:24:13           1      0.00   2.5
# 6357 2019-03-19 10:43:58 2019-03-19 10:44:07           1      0.00   2.5
# 6372 2019-03-20 14:24:28 2019-03-20 14:24:32           1      0.00   2.5
# 6393 2019-03-10 18:33:13 2019-03-10 19:32:38           1      0.00  71.2
#
#        tip  tolls  total   color      payment                pickup_zone  \
# ...

# %%
sns.jointplot(x = df['distance'], y = df['tip'], kind="reg")

# %%
df[df['distance']==0].shape[0]
# Out:
# 32

# %%
df[df['tip']==0].shape[0]
# Out:
# 2244

# %%
df.drop(df[df['tip']==0].index, inplace=True)

# %%
sns.jointplot(x = df['distance'], y = df['tip'], kind="reg")

# %%
sns.pairplot(df)

# %%
sns.barplot(x = df['pickup_borough'], y = df['total'], hue=df['pickup_borough'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
df[df['pickup_borough']=="Manhattan"]["total"].mean()
# Out:
# 17.617307692307694

# %%
df[df['pickup_borough']=="Queens"]["total"].mean()
# Out:
# 41.453791946308726

# %% [markdown]
# # Uygulama 2 - Banka Müşterisi Uygulaması

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip
# Out:
# --2024-10-09 17:09:28--  https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘bank-additional.zip’
#
# bank-additional.zip     [   <=>              ] 434.15K   672KB/s    in 0.6s
#
# 2024-10-09 17:09:29 (672 KB/s) - ‘bank-additional.zip’ saved [444572]

# %%
# !unzip -o -q bank-additional.zip

# %%
df = pd.read_csv("bank-additional-full.csv", sep=";")
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
df.shape
# Out:
# (41188, 21)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                   count         mean         std       min       25%  \
# age             41188.0    40.024060   10.421250    17.000    32.000
# duration        41188.0   258.285010  259.279249     0.000   102.000
# campaign        41188.0     2.567593    2.770014     1.000     1.000
# pdays           41188.0   962.475454  186.910907     0.000   999.000
# previous        41188.0     0.172963    0.494901     0.000     0.000
# emp.var.rate    41188.0     0.081886    1.570960    -3.400    -1.800
# cons.price.idx  41188.0    93.575664    0.578840    92.201    93.075
# cons.conf.idx   41188.0   -40.502600    4.628198   -50.800   -42.700
# euribor3m       41188.0     3.621291    1.734447     0.634     1.344
# nr.employed     41188.0  5167.035911   72.251528  4963.600  5099.100
#
#                      50%       75%       max
# age               38.000    47.000    98.000
# duration         180.000   319.000  4918.000
# campaign           2.000     3.000    56.000
# ...

# %%
df.describe(include=["object"]).T
# Out:
#              count unique                top   freq
# job          41188     12             admin.  10422
# marital      41188      4            married  24928
# education    41188      8  university.degree  12168
# default      41188      3                 no  32588
# housing      41188      3                yes  21576
# loan         41188      3                 no  33950
# contact      41188      2           cellular  26144
# month        41188     10                may  13769
# day_of_week  41188      5                thu   8623
# poutcome     41188      3        nonexistent  35563
# y            41188      2                 no  36548

# %%
df["y"].value_counts()
# Out:
# y
# no     36548
# yes     4640
# Name: count, dtype: int64

# %%
4640/41188
# Out:
# 0.11265417111780131

# %%
df["marital"].value_counts()
# Out:
# marital
# married     24928
# single      11568
# divorced     4612
# unknown        80
# Name: count, dtype: int64

# %%
df["marital"].value_counts(normalize=True)
# Out:
# marital
# married     0.605225
# single      0.280859
# divorced    0.111974
# unknown     0.001942
# Name: proportion, dtype: float64

# %%
df.sort_values(by = "duration", ascending = False)
# Out:
#        age          job   marital            education default housing loan  \
# 24091   33   technician    single  professional.course      no     yes   no
# 22192   52  blue-collar   married             basic.4y      no      no   no
# 40537   27       admin.    single          high.school      no      no   no
# 13820   31   technician   married  professional.course      no      no   no
# 7727    37   unemployed   married  professional.course      no     yes   no
# ...    ...          ...       ...                  ...     ...     ...  ...
# 40554   72      retired   married  professional.course      no      no   no
# 28063   53  blue-collar  divorced          high.school      no     yes   no
# 33015   31  blue-collar   married             basic.9y      no      no   no
# 23031   59   management   married    university.degree      no     yes   no
# 6251    39       admin.   married          high.school      no     yes   no
#
# ...

# %%
df.sort_values(by = ["age","duration"], ascending = [True, False]).head()
# Out:
#        age      job marital education default  housing     loan   contact  \
# 38274   17  student  single   unknown      no       no      yes  cellular
# 37579   17  student  single  basic.9y      no  unknown  unknown  cellular
# 37140   17  student  single   unknown      no      yes       no  cellular
# 37539   17  student  single  basic.9y      no      yes       no  cellular
# 37558   17  student  single  basic.9y      no      yes       no  cellular
#
#       month day_of_week  ...  campaign  pdays  previous  poutcome  \
# 38274   oct         tue  ...         1      2         2   success
# 37579   aug         fri  ...         2    999         1   failure
# 37140   aug         wed  ...         3      4         2   success
# 37539   aug         fri  ...         2    999         2   failure
# 37558   aug         fri  ...         3      4         2   success
#
#       emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed    y
# ...

# %%
d = {"no": 0, "yes": 1}
df["y"] = df["y"].map(d)
df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
print("Kaç müşteri de başarı sağlanmıştır =", '{:.1%}'.format(df["y"].mean()))
# Out:
# Kaç müşteri de başarı sağlanmıştır = 11.3%

# %%
df[df["y"] == 1]["duration"].mean()
# Out:
# 553.1911637931034

# %%
df[df["y"] == 1].shape[0]
# Out:
# 4640

# %%
4640/41188
# Out:
# 0.11265417111780131

# %%
round(df[(df["y"] == 1) & (df["marital"] == "single")]["age"].mean(), 0)
# Out:
# 31.0

# %%
pd.crosstab(df["y"], df["marital"]).T
# Out:
# y             0     1
# marital
# divorced   4136   476
# married   22396  2532
# single     9948  1620
# unknown      68    12

# %%
pd.crosstab(df["y"], df["marital"], normalize="index").T
# Out:
# y                0         1
# marital
# divorced  0.113166  0.102586
# married   0.612783  0.545690
# single    0.272190  0.349138
# unknown   0.001861  0.002586

# %%
df.pivot_table(
        ["age", "duration"],
        ["job"],
        aggfunc = "mean"
)
# Out:
#                      age    duration
# job
# admin.         38.187296  254.312128
# blue-collar    39.555760  264.542360
# entrepreneur   41.723214  263.267857
# housemaid      45.500000  250.454717
# management     42.362859  257.058140
# retired        62.027326  273.712209
# self-employed  39.949331  264.142153
# services       37.926430  258.398085
# student        25.894857  283.683429
# technician     38.507638  250.232241
# unemployed     39.733728  249.451677
# unknown        45.563636  239.675758

# %%
pd.plotting.scatter_matrix(
        df[["age", "duration", "campaign"]],
            figsize = (15, 15),
            diagonal = "kde")
plt.show()

# %%
df["age"].hist()
# Out:
# <Axes: >

# %%
df.boxplot(column = "age",
          by = "marital")
plt.show()
