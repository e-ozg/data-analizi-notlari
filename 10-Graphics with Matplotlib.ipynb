# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4],[1,4,9,16])

# %%
plt.plot([5,10,15,20],[1,2,1.5,4])

# %%
plt.plot([1,2,3,4],[1,4,9,16],"ro")

# %%
plt.figure(figsize=(8,6))
plt.axis([0,5,0,20])
plt.title('Satışlar')
plt.plot([1,2,3,4],[1,4,9,16],"ro")
plt.show()
